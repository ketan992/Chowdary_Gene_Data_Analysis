# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('chowdary.csv')
df
# Out:
#     Unnamed: 0 tumour  X201123_s_at  X201262_s_at  X201496_x_at  X201497_x_at  \
# 0     GSM85863      B          38.5          77.2          10.0          10.0
# 1     GSM85864      B          82.7          13.4          31.8         338.4
# 2     GSM85865      B          54.8         111.1          16.3         119.0
# 3     GSM85866      B          41.1          96.3          11.2          76.4
# 4     GSM85867      B          30.5         117.3          18.4         139.4
# ..         ...    ...           ...           ...           ...           ...
# 99    GSM85962      C         190.4          71.1          10.0          10.0
# 100   GSM85963      C         125.2          10.0          10.0          32.8
# 101   GSM85964      C         182.8          10.0          10.0          51.7
# 102   GSM85965      C          10.0          10.0         359.5         929.9
# 103   GSM85966      C          10.0          13.4          10.0          34.6
#
# ...

# %%
df = df.drop(df.columns[[0]],axis = 1)

# %%
df
# Out:
#     tumour  X201123_s_at  X201262_s_at  X201496_x_at  X201497_x_at  \
# 0        B          38.5          77.2          10.0          10.0
# 1        B          82.7          13.4          31.8         338.4
# 2        B          54.8         111.1          16.3         119.0
# 3        B          41.1          96.3          11.2          76.4
# 4        B          30.5         117.3          18.4         139.4
# ..     ...           ...           ...           ...           ...
# 99       C         190.4          71.1          10.0          10.0
# 100      C         125.2          10.0          10.0          32.8
# 101      C         182.8          10.0          10.0          51.7
# 102      C          10.0          10.0         359.5         929.9
# 103      C          10.0          13.4          10.0          34.6
#
#      X201525_at  X201884_at  X201909_at  X202018_s_at  X202037_s_at  ...  \
# 0          65.7        12.9        10.4          30.1         418.6  ...
# ...

# %%
y = df['tumour']
X = df.drop(columns = ['tumour'])
X
# Out:
#      X201123_s_at  X201262_s_at  X201496_x_at  X201497_x_at  X201525_at  \
# 0            38.5          77.2          10.0          10.0        65.7
# 1            82.7          13.4          31.8         338.4        93.3
# 2            54.8         111.1          16.3         119.0       361.3
# 3            41.1          96.3          11.2          76.4       435.5
# 4            30.5         117.3          18.4         139.4       917.0
# ..            ...           ...           ...           ...         ...
# 99          190.4          71.1          10.0          10.0       118.3
# 100         125.2          10.0          10.0          32.8        13.0
# 101         182.8          10.0          10.0          51.7        18.0
# 102          10.0          10.0         359.5         929.9        78.0
# 103          10.0          13.4          10.0          34.6        13.5
#
#      X201884_at  X201909_at  X202018_s_at  X202037_s_at  X202286_s_at  ...  \
# ...
